# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
degree = np.loadtxt("degree.txt")

# %%
plt.hist(degree)
plt.xlabel("degree")
plt.ylabel("")
plt.show()

# %%
components = np.loadtxt("components.txt")

# %%
plt.hist(components)
plt.xlabel("components")
plt.ylabel("")
plt.show()
